# %% [markdown]
# <a href="https://colab.research.google.com/github/pzoliveira/DSFirstSteps/blob/main/DSFirstSteps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importando as bibliotecas

# %%
import pandas as pd

# %%
base_credito = pd.read_csv('credit_risk_dataset.csv')

# %%
base_credito
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
type(base_credito)
# Out:
# pandas.core.frame.DataFrame

# %%
base_credito.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  32581.000000   3.258100e+04       31686.000000  32581.000000
# mean      27.734600   6.607485e+04           4.789686   9589.371106
# std        6.348078   6.198312e+04           4.142630   6322.086646
# min       20.000000   4.000000e+03           0.000000    500.000000
# 25%       23.000000   3.850000e+04           2.000000   5000.000000
# 50%       26.000000   5.500000e+04           4.000000   8000.000000
# 75%       30.000000   7.920000e+04           7.000000  12200.000000
# max      144.000000   6.000000e+06         123.000000  35000.000000
#
#        loan_int_rate   loan_status  loan_percent_income  \
# count   29465.000000  32581.000000         32581.000000
# mean       11.011695      0.218164             0.170203
# std         3.240459      0.413006             0.106782
# min         5.420000      0.000000             0.000000
# 25%         7.900000      0.000000             0.090000
# ...

# %%
pd.set_option('display.float_format', lambda x: '%.3f' %x)

# %%
base_credito.describe()
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# count   32581.000      32581.000          31686.000  32581.000      29465.000
# mean       27.735      66074.848              4.790   9589.371         11.012
# std         6.348      61983.119              4.143   6322.087          3.240
# min        20.000       4000.000              0.000    500.000          5.420
# 25%        23.000      38500.000              2.000   5000.000          7.900
# 50%        26.000      55000.000              4.000   8000.000         10.990
# 75%        30.000      79200.000              7.000  12200.000         13.470
# max       144.000    6000000.000            123.000  35000.000         23.220
#
#        loan_status  loan_percent_income  cb_person_cred_hist_length
# count    32581.000            32581.000                   32581.000
# mean         0.218                0.170                       5.804
# ...

# %%
base_credito[base_credito['person_income'] >= 6000000]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 32297         144        6000000              MORTGAGE             12.000
#
#       loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 32297    PERSONAL          C       5000         12.730            0
#
#        loan_percent_income cb_person_default_on_file  \
# 32297                0.000                         N
#
#        cb_person_cred_hist_length
# 32297                          25
