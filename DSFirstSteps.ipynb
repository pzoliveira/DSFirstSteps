# %% [markdown]
# <a href="https://colab.research.google.com/github/pzoliveira/DSFirstSteps/blob/main/DSFirstSteps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importando as bibliotecas

# %%
import pandas as pd

# %%
df = pd.read_csv('credit_risk_dataset.csv')

# %%
df
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT            123.000
# 1              21           9600                   OWN              5.000
# 2              25           9600              MORTGAGE              1.000
# 3              23          65500                  RENT              4.000
# 4              24          54400                  RENT              8.000
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE              1.000
# 32577          54         120000              MORTGAGE              4.000
# 32578          65          76000                  RENT              3.000
# 32579          56         150000              MORTGAGE              5.000
# 32580          66          42000                  RENT              2.000
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# 0             PERSONAL          D      35000         16.020            1
# 1            EDUCATION          B       1000         11.140            0
# 2              MEDICAL          C       5500         12.870            1
# 3              MEDICAL          C      35000         15.230            1
# 4              MEDICAL          C      35000         14.270            1
# ...                ...        ...        ...            ...          ...
# 32576         PERSONAL          C       5800         13.160            0
# 32577         PERSONAL          A      17625          7.490            0
# 32578  HOMEIMPROVEMENT          B      35000         10.990            1
# 32579         PERSONAL          B      15000         11.480            0
# 32580          MEDICAL          B       6475          9.990            0
#
#        loan_percent_income cb_person_default_on_file  \
# 0                    0.590                         Y
# 1                    0.100                         N
# 2                    0.570                         N
# 3                    0.530                         N
# 4                    0.550                         Y
# ...                    ...                       ...
# 32576                0.110                         N
# 32577                0.150                         N
# 32578                0.460                         N
# 32579                0.100                         N
# 32580                0.150                         N
#
#        cb_person_cred_hist_length
# 0                               3
# 1                               2
# 2                               3
# 3                               2
# 4                               4
# ...                           ...
# 32576                          30
# 32577                          19
# 32578                          28
# 32579                          26
# 32580                          30
#
# [32581 rows x 12 columns]

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Selecionando colunas do dataset

# %%
base_credito= df[df.columns[df.columns.isin({'person_age', 'person_income', 'loan_amnt', 'loan_status'})]]

# %%
base_credito
# Out:
#        person_age  person_income  loan_amnt  loan_status
# 0              22          59000      35000            1
# 1              21           9600       1000            0
# 2              25           9600       5500            1
# 3              23          65500      35000            1
# 4              24          54400      35000            1
# ...           ...            ...        ...          ...
# 32576          57          53000       5800            0
# 32577          54         120000      17625            0
# 32578          65          76000      35000            1
# 32579          56         150000      15000            0
# 32580          66          42000       6475            0
#
# [32581 rows x 4 columns]

# %% [markdown]
# # Medidas Estatísticas

# %%
base_credito.describe()
# Out:
#        person_age  person_income  loan_amnt  loan_status
# count   32581.000      32581.000  32581.000    32581.000
# mean       27.735      66074.848   9589.371        0.218
# std         6.348      61983.119   6322.087        0.413
# min        20.000       4000.000    500.000        0.000
# 25%        23.000      38500.000   5000.000        0.000
# 50%        26.000      55000.000   8000.000        0.000
# 75%        30.000      79200.000  12200.000        0.000
# max       144.000    6000000.000  35000.000        1.000

# %%
pd.set_option('display.float_format', lambda x: '%.3f' %x)

# %%
base_credito.describe()
# Out:
#        person_age  person_income  loan_amnt  loan_status
# count   32581.000      32581.000  32581.000    32581.000
# mean       27.735      66074.848   9589.371        0.218
# std         6.348      61983.119   6322.087        0.413
# min        20.000       4000.000    500.000        0.000
# 25%        23.000      38500.000   5000.000        0.000
# 50%        26.000      55000.000   8000.000        0.000
# 75%        30.000      79200.000  12200.000        0.000
# max       144.000    6000000.000  35000.000        1.000

# %%
base_credito[base_credito['person_income'] >= 6000000]
# Out:
#        person_age  person_income  loan_amnt  loan_status
# 32297         144        6000000       5000            0

# %%
base_credito[base_credito['person_income'] <=4000]
# Out:
#        person_age  person_income  loan_amnt  loan_status
# 31930          41           4000       2000            1
